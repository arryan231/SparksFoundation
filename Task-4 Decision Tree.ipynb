# %% [markdown]
# # The Sparks Foundation- Data Science Internship
# Task 4 - Decision Tree
#
# The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# Data can be found at https://bit.ly/3kXTdox

# %%
#importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.tree import export_text

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop(['Id'],axis='columns',inplace=True)

# %%
#data visualization
df.hist(figsize = (12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017590871D60>,
# ...
#       dtype=object)

# %%
sns.pairplot(df)

# %%
X=df.drop(['Species'],axis='columns',inplace=False)
y=df.Species

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state =4)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Prediction

# %%
pred=clf.predict(X_train)

# %%
#Accuracy for train
print("Accuracy : ",accuracy_score(pred,y_train)*100,"%")
# Out:
# Accuracy:  100.0 %

# %%
#Accuracy for test
pred=clf.predict(X_test)
print("Accuracy for the model: ",accuracy_score(pred,y_test)*100,"%")
# Out:
# Accuracy for the model:  96.66666666666667 %

# %%
#confusing matrix for test
confusion_matrix(pred,y_test)
sns.heatmap(confusion_matrix(pred,y_test),annot = True,cmap = 'BuGn')
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(33.0, 0.5, 'Actual')

# %%
plt.figure(figsize  = (15,15))
tree.plot_tree(clf,filled = True,rounded = True,proportion = True,node_ids = True)
plt.show()

# %%
print(tree.export_text(clf))
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica
